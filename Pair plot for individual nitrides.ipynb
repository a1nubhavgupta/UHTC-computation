# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_csv("individual nitride and features.csv")

selected_features = ['Pseudorad', 'Pauling electronegativity difference']

sns.pairplot(df, hue='Formation', vars=selected_features, height=2)
plt.savefig("pair_plot.png")
plt.show()
# Out:
# /Users/anubhavgupta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
selected_features1 = ['Pseudorad', 'Cohesive energy']

sns.pairplot(df, hue='Formation', vars=selected_features1, height=2)
plt.savefig("pair_plot1.png")
plt.show()
# Out:
# /Users/anubhavgupta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
selected_features2 = ['Pseudorad', 'Melting point']

sns.pairplot(df, hue='Formation', vars=selected_features2, height=2)
plt.savefig("pair_plot2.png")
plt.show()
# Out:
# /Users/anubhavgupta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
selected_features3 = ['Pseudorad', 'Molar volume']

sns.pairplot(df, hue='Formation', vars=selected_features3, height=2)
plt.savefig("pair_plot3.png")
plt.show()
# Out:
# /Users/anubhavgupta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
selected_features4 = ['Pseudorad', 'Density']

sns.pairplot(df, hue='Formation', vars=selected_features4, height=2)
plt.savefig("pair_plot4.png")
plt.show()
# Out:
# /Users/anubhavgupta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
selected_features5 = ['Pseudorad', 'Molar mass']

sns.pairplot(df, hue='Formation', vars=selected_features5, height=2)
plt.savefig("pair_plot5.png")
plt.show()
# Out:
# /Users/anubhavgupta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
selected_features6 = ['Pseudorad', 'Covalent radius']

sns.pairplot(df, hue='Formation', vars=selected_features6, height=2)
plt.savefig("pair_plot6.png")
plt.show()
# Out:
# /Users/anubhavgupta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
selected_features7 = ['Pseudorad', 'VEC']

g = sns.pairplot(df, hue='Formation', vars=selected_features7, height=2)
plt.savefig("pair_plot7.png")

condition_single_phase = (df['Formation'] == 'Yes')& (df['VEC'] >= 3)& (df['VEC']<=6)&(df['Pseudorad'] >= 2.180)& (df["Pseudorad"]<=2.540)
condition_single_phase1 = (df['Formation'] == 'No')& (df['VEC'] >= 3)& (df['VEC']<=6)&(df['Pseudorad'] >= 2.180)& (df["Pseudorad"]<=2.540) 

coordinates_single_phase = df.loc[condition_single_phase, selected_features7]
coordinates_single_phase1 = df.loc[condition_single_phase1, selected_features7]

print("Coordinates for yes Phase components:\n", coordinates_single_phase)
print("Coordinates for no Phase components:\n", coordinates_single_phase1)

            
plt.show()
# Out:
# /Users/anubhavgupta/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Coordinates for yes Phase components:
#      Pseudorad  VEC
# 1       2.285    4
# 2       2.370    4
# 3       2.210    3
# 8       2.400    3
# 9       2.220    5
# 10      2.180    6
# 13      2.250    5
# 14      2.195    6
# 28      2.540    3
# Coordinates for no Phase components:
#  Empty DataFrame
# Columns: [Pseudorad, VEC]
# Index: []
